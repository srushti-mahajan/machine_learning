# %% [markdown]
# ASSIGNMENT=01

# %%
## Descriptive Analytics and Data Preprocessing on Sales & Discount Dataset

# %%
## Descriptive Analytics For Numerical Columns

# %%
## Objective:To compute and analyze basic statistical measures for numerical columns in dataset.

# %%
#import important librabries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib .pyplot as plt

# %%
#load the datasets
df=pd.read_csv("sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        12100             181500          11.654820     21153.498820
# 1        10100             101000          11.560498     11676.102960
# 2        16100             112700           9.456886     10657.910160
# 3        20100             120600           6.935385      8364.074702
# 4         8100              24300          17.995663      4372.946230
# ..         ...                ...                ...              ...
# 445       1300               2600          15.475687       402.367873
# 446       2600              15600          17.057027      2660.896242
# 447       1600               3200          18.965550       606.897606
# 448       1900               5700          16.793014       957.201826
# 449       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# 0      160346.501200
# 1       89323.897040
# 2      102042.089800
# 3      112235.925300
# 4       19927.053770
# ..               ...
# 445      2197.632127
# 446     12939.103760
# 447      2593.102394
# 448      4742.798174
# 449      2624.667705
#
# [450 rows x 13 columns]

# %%
#Identify the columns
df. columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
#Identify the dtypes of each column
df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
# Extract Numeric Columns
n=df.select_dtypes(include=np.number).columns
n
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
#Calculate Mean,Median and Standard deviation of this Columns
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495426     47847.912855
# max       25738.022190    179507.479000

# %%
# mode for numerical data

# %%
df['Volume'].mode().iloc[0]
# Out:
# 3

# %%
df['Avg Price'].mode().iloc[0]
# Out:
# 400

# %%
df['Total Sales Value'].mode().iloc[0]
# Out:
# 24300

# %%
df['Discount Rate (%)'].mode().iloc[0]
# Out:
# 5.007822189

# %%
# 2.Data Visualization

# %%
#Histograms

# %%
plt.hist(df['Volume'], bins=20, color='pink', edgecolor='black')
plt.title('Distribution of Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Avg Price'], bins=20, color='pink', edgecolor='black')
plt.title('Distribution of Avg Price')
plt.xlabel('Avg Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Discount Rate (%)'], bins=20, color='pink', edgecolor='black')
plt.title('Distribution of Discount Rate (%) ')
plt.xlabel('Discount Rate (%)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Total Sales Value'], bins=20, color='pink', edgecolor='black')
plt.title('Distribution of Total Sales Value ')
plt.xlabel('Total Sales Value')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Discount Amount'], bins=20, color='pink', edgecolor='black')
plt.title('Distribution of Discount Amount  ')
plt.xlabel('Discount Amount')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Net Sales Value'] ,bins=20, color='pink', edgecolor='black')
plt.title('Distribution of Net Sales Value ')
plt.xlabel('Net Sales Value')
plt.ylabel('Frequency')
plt.show()

# %%
#Outlier detection by boxplot method
fig,ax = plt.subplots(figsize=(10,5))
df.boxplot(grid=False,ax=ax)
plt.title("Outlier Detection")
plt.show()

# %%
#Identify the categorical data and create bar chart

# %%
df.describe(include='object')
# Out:
#               Date       Day  SKU City       BU  Brand  Model
# count          450       450  450  450      450    450    450
# unique          15         7   30    1        3      9     30
# top     01-04-2021  Thursday  M01    C  Mobiles  Jeera  RU-10
# freq            30        90   15  450      150     90     15

# %%
plt.figure(figsize=(5, 5))
df['City'].value_counts().plot(kind='bar', color='pink')
plt.title('Bar Chart of City')
plt.xlabel('City')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(5, 5))
df['Brand'].value_counts().plot(kind='bar', color='pink')
plt.title('Bar Chart of Brand')
plt.xlabel('Brand')
plt.ylabel('Frequency')
plt.show()

# %%
# 3.Standardization of Numerical Variables

# %% [markdown]
# ### Explanation of Standardization (Z-score Normalization)
#
# Standardization, also known as Z-score normalization, is a technique used to transform numerical variables to have a mean of 0 and a standard deviation of 1. This process involves subtracting the mean (mu) from each value and then dividing by the standard deviation (sigma).
# This standardizes the distribution of the data, making it easier to compare variables with different scales and improving the performance of analytical models

# %%
df.describe()
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495426     47847.912855
# max       25738.022190    179507.479000

# %%
#for standardization  import important librabries
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
#Standardization
n=df.select_dtypes(include=np.number).columns
n
# Out:
# Index(['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
sc = StandardScaler()

# %%
sc.fit_transform(df[n])
# Out:
# array([[ 2.35002911,  0.091173  ,  2.92572115, -0.83028851,  3.95281631,
#          2.80475594],
#        [ 1.16712855, -0.01957016,  1.33099521, -0.85266145,  1.84901409,
#          1.2710262 ],
#        [ 0.45738822,  0.31265934,  1.56277525, -1.35163138,  1.62299459,
#          1.54567497],
#        ...,
#        [-0.72551234, -0.49022863, -0.60644824,  0.90379261, -0.60813967,
#         -0.60192115],
#        [-0.48893223, -0.47361715, -0.55692259,  0.38847428, -0.53037877,
#         -0.55549857],
#        [-0.96209245, -0.40717125, -0.60842926,  0.04223476, -0.63734468,
#         -0.60123949]])

# %%
# Create DataFrame for this array type data
pd.DataFrame(sc.fit_transform(df[n]))
# Out:
#             0         1         2         3         4         5
# 0    2.350029  0.091173  2.925721 -0.830289  3.952816  2.804756
# 1    1.167129 -0.019570  1.330995 -0.852661  1.849014  1.271026
# 2    0.457388  0.312659  1.562775 -1.351631  1.622995  1.545675
# 3    0.220808  0.534146  1.719276 -1.949723  1.113807  1.765810
# 4   -0.488932 -0.130313 -0.188452  0.673739  0.227852 -0.227595
# ..        ...       ...       ...       ...       ...       ...
# 445 -0.725512 -0.506840 -0.618334  0.076009 -0.653541 -0.610461
# 446  0.220808 -0.434857 -0.360801  0.451097 -0.152191 -0.378500
# 447 -0.725512 -0.490229 -0.606448  0.903793 -0.608140 -0.601921
# 448 -0.488932 -0.473617 -0.556923  0.388474 -0.530379 -0.555499
# 449 -0.962092 -0.407171 -0.608429  0.042235 -0.637345 -0.601239
#
# [450 rows x 6 columns]

# %%
numerical_columns = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
numerical_columns
# Out:
# ['Volume',
#  'Avg Price',
#  'Total Sales Value',
#  'Discount Rate (%)',
#  'Discount Amount',
#  'Net Sales Value']

# %%
scaled_data=pd.DataFrame(sc.fit_transform(df[n]),columns=numerical_columns)
scaled_data
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.350029   0.091173           2.925721          -0.830289
# 1    1.167129  -0.019570           1.330995          -0.852661
# 2    0.457388   0.312659           1.562775          -1.351631
# 3    0.220808   0.534146           1.719276          -1.949723
# 4   -0.488932  -0.130313          -0.188452           0.673739
# ..        ...        ...                ...                ...
# 445 -0.725512  -0.506840          -0.618334           0.076009
# 446  0.220808  -0.434857          -0.360801           0.451097
# 447 -0.725512  -0.490229          -0.606448           0.903793
# 448 -0.488932  -0.473617          -0.556923           0.388474
# 449 -0.962092  -0.407171          -0.608429           0.042235
#
#      Discount Amount  Net Sales Value
# 0           3.952816         2.804756
# 1           1.849014         1.271026
# 2           1.622995         1.545675
# 3           1.113807         1.765810
# 4           0.227852        -0.227595
# ..               ...              ...
# 445        -0.653541        -0.610461
# 446        -0.152191        -0.378500
# 447        -0.608140        -0.601921
# 448        -0.530379        -0.555499
# 449        -0.637345        -0.601239
#
# [450 rows x 6 columns]

# %%
#AGAIN TAKE A SUMMERY OF NUMERICAL DATASET
scaled_data.describe()
# Out:
#              Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  4.500000e+02  4.500000e+02       4.500000e+02       4.500000e+02
# mean   6.118562e-17  3.157968e-17       1.578984e-17       4.855375e-16
# std    1.001113e+00  1.001113e+00       1.001113e+00       1.001113e+00
# min   -9.620925e-01 -5.627654e-01      -6.619170e-01      -2.406935e+00
# 25%   -4.889322e-01 -5.530754e-01      -6.163534e-01      -2.823066e-01
# 50%   -2.523521e-01 -4.985344e-01      -5.569226e-01       3.374180e-01
# 75%    2.208081e-01 -1.957016e-02       3.840648e-01       7.019781e-01
# max    6.135311e+00  2.749009e+00       3.220894e+00       1.147360e+00
#
#        Discount Amount  Net Sales Value
# count     4.500000e+02     4.500000e+02
# mean      5.526444e-17    -7.105427e-17
# std       1.001113e+00     1.001113e+00
# min      -7.275032e-01    -6.508581e-01
# 25%      -6.406462e-01    -6.103625e-01
# 50%      -5.233349e-01    -5.569025e-01
# 75%       4.373018e-01     3.753543e-01
# max       4.970494e+00     3.218536e+00

# %%
# Displaying comparison of data distributions before and after standardization
for column in numerical_columns:
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.hist(df[column], bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {column} (Before Standardization)')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.subplot(1, 2, 2)
    plt.hist(df[column], bins=20, color='salmon', edgecolor='black')
    plt.title(f'Distribution of {column} (After Standardization)')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
# Conversion of Categorical Data into Dummy Variables

# %%
#### Need for Converting Categorical Data into Dummy Variables (One-Hot Encoding)

#In many machine learning algorithms, categorical variables cannot be directly used as inputs. One-hot encoding is a technique used to convert categorical variables into a format that can be provided to machine learning algorithms. 
#It creates binary (0 or 1) columns for each category in the categorical variable. This ensures that the categorical data is represented in a numerical format, allowing machine learning models to interpret and process it effectively.

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102960
# 2      16100             112700           9.456886     10657.910160
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0     160346.50120
# 1      89323.89704
# 2     102042.08980
# 3     112235.92530
# 4      19927.05377

# %%
#One-Hot Encoding

# %%
#performing one-hot encoding on categorical columns
sales_data=pd.get_dummies(df)
sales_data
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102960
# 2         7      16100             112700           9.456886     10657.910160
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0      160346.501200             True            False            False
# 1       89323.897040             True            False            False
# 2      102042.089800             True            False            False
# 3      112235.925300             True            False            False
# 4       19927.053770             True            False            False
# ..               ...              ...              ...              ...
# 445      2197.632127            False            False            False
# 446     12939.103760            False            False            False
# 447      2593.102394            False            False            False
# 448      4742.798174            False            False            False
# 449      2624.667705            False            False            False
#
#      Date_04-04-2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# 0              False  ...              False            False
# 1              False  ...              False            False
# 2              False  ...              False            False
# 3              False  ...              False            False
# 4              False  ...              False            False
# ..               ...  ...                ...              ...
# 445            False  ...              False            False
# 446            False  ...              False            False
# 447            False  ...              False            False
# 448            False  ...              False            False
# 449            False  ...              False            False
#
#      Model_Vedic Shampoo  Model_W-Casuals  Model_W-Inners  Model_W-Lounge  \
# 0                  False            False           False           False
# 1                  False            False           False           False
# 2                  False            False           False           False
# 3                  False            False           False           False
# 4                  False            False           False           False
# ..                   ...              ...             ...             ...
# 445                False            False           False           False
# 446                False            False           False           False
# 447                False            False           False            True
# 448                False            False           False           False
# 449                False            False           False           False
#
#      Model_W-Western  Model_YM-98   Model_YM-99  Model_YM-99 Plus
# 0              False         False        False             False
# 1              False         False        False             False
# 2              False         False         True             False
# 3              False         False        False              True
# 4              False          True        False             False
# ..               ...           ...          ...               ...
# 445            False         False        False             False
# 446             True         False        False             False
# 447            False         False        False             False
# 448            False         False        False             False
# 449            False         False        False             False
#
# [450 rows x 101 columns]

# %%
sales_data.head()
# Out:
#    Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      15      12100             181500          11.654820     21153.498820
# 1      10      10100             101000          11.560498     11676.102960
# 2       7      16100             112700           9.456886     10657.910160
# 3       6      20100             120600           6.935385      8364.074702
# 4       3       8100              24300          17.995663      4372.946230
#
#    Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0     160346.50120             True            False            False
# 1      89323.89704             True            False            False
# 2     102042.08980             True            False            False
# 3     112235.92530             True            False            False
# 4      19927.05377             True            False            False
#
#    Date_04-04-2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# 0            False  ...              False            False
# 1            False  ...              False            False
# 2            False  ...              False            False
# 3            False  ...              False            False
# 4            False  ...              False            False
#
#    Model_Vedic Shampoo  Model_W-Casuals  Model_W-Inners  Model_W-Lounge  \
# 0                False            False           False           False
# 1                False            False           False           False
# 2                False            False           False           False
# 3                False            False           False           False
# 4                False            False           False           False
#
#    Model_W-Western  Model_YM-98   Model_YM-99  Model_YM-99 Plus
# 0            False         False        False             False
# 1            False         False        False             False
# 2            False         False         True             False
# 3            False         False        False              True
# 4            False          True        False             False
#
# [5 rows x 101 columns]

# %%
#Conclusion

# %%
#### Key Findings from Descriptive Analytics and Data Visualizations

1. Numerical Columns:
   - The mean Volume of sales is 5.07 units, with a median of 4 units, indicating a slightly right-skewed distribution.
   - Total Sales Value has a mean of 33812.84 and a median of 5700, suggesting a right-skewed distribution with some transactions having 
     considerably higher sales values.
   - Discount Amount and Net Sales Value exhibit similar patterns, with a wide range of values and a right-skewed distribution.

2. Data Visualization:
   - Histograms and boxplots revealed the distribution and presence of outliers in numerical variables.
   - Bar charts for categorical columns illustrated the frequency of transactions in each category, providing insights into the distribution of 
     sales across different cities and brands.

# %% [markdown]
# In conclusion, data preprocessing steps like standardization and one-hot encoding are essential for ensuring the quality and usability of the dataset in data analysis and machine learning tasks. These steps enable us to extract meaningful insights, build accurate models, and make informed decisions based on the data.

# %% [markdown]
#                                                               Thank You
